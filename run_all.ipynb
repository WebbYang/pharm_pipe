# %%
import pandas as pd
# %pylab inline

df = pd.read_csv('data/MMI_gender_prediction.csv', index_col=0)
df.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib
#         chrX_mean_depth pred_gender gender  consistent
# MMI001        19.322773           M      M        True
# MMI002        37.040048           F      F        True
# MMI003        23.854752           M      M        True
# MMI004        46.977884           F      F        True
# MMI005        30.219566           F      F        True

# %%
for subject in df.index[21:]:
    print(subject)
    sex = df.loc[subject, 'gender']
    ! python3 star_call.py --id {subject} --out out/{subject} --sex {sex}
# Out:
# MMI011
# INFO:root:Processing sample MMI011.realigned at 2022-03-02 00:41:14.997018
# INFO:root:Writing to json at 2022-03-02 00:41:52.906988
# INFO:root:Writing to tsv at 2022-03-02 00:41:52.909281
# Call Cyrius to out/MMI011/cyrius_MMI011 done!
# 🐿  Aldy v3.3 (Python 3.7.9 on Linux 4.18.0-305.3.1.el8.x86_64-x86_64-with-centos-8.3.2011)
#    (c) 2016-2022 Aldy Authors. All rights reserved.
#    Free for non-commercial/academic use only.
# Genotyping sample MMI011.realigned.bam...
# Potential CFTR gene structures for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Potential major CFTR star-alleles for MMI011.realigned:
#    1: 2x*normal (confidence: 100%)
# Best CFTR star-alleles for MMI011.realigned:
#    1: *normal / *normal (confidence=100%)
#       Minor alleles: *normal, *normal
# CFTR results:
#   - *normal / *normal
#     Minor: [*normal] / [*normal]
#     Legacy notation: [*normal] / [*normal]
# 🐿  Aldy v3.3 (Python 3.7.9 on Linux 4.18.0-305.3.1.el8.x86_64-x86_64-with-centos-8.3.2011)
#    (c) 2016-2022 Aldy Authors. All rights reserved.
#    Free for non-commercial/academic use only.
# Genotyping sample MMI011.realigned.bam...
# Potential CYP2B6 gene structures for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Potential major CYP2B6 star-alleles for MMI011.realigned:
#    1: 1x*4, 1x*6 (confidence: 100%)
# Best CYP2B6 star-alleles for MMI011.realigned:
#    1: *4 / *6 (confidence=100%)
#       Minor alleles: *4.002 +rs7254579, *6.003
# CYP2B6 results:
#   - *4 / *6
#     Minor: [*4.002 +rs7254579] / [*6.003]
#     Legacy notation: [*4D +rs7254579] / [*6C]
# 🐿  Aldy v3.3 (Python 3.7.9 on Linux 4.18.0-305.3.1.el8.x86_64-x86_64-with-centos-8.3.2011)
#    (c) 2016-2022 Aldy Authors. All rights reserved.
#    Free for non-commercial/academic use only.
# Genotyping sample MMI011.realigned.bam...
# Potential CYP2C19 gene structures for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Potential major CYP2C19 star-alleles for MMI011.realigned:
#    1: 1x*1B, 1x*3 (confidence: 100%)
# Best CYP2C19 star-alleles for MMI011.realigned:
#    1: *1B / *3 (confidence=100%)
#       Minor alleles: *1.005 +rs17885098, *3.001
# CYP2C19 results:
#   - *1B / *3
#     Minor: [*1.005 +rs17885098] / [*3.001]
#     Legacy notation: [*1.005 +rs17885098] / [*3A]
# 🐿  Aldy v3.3 (Python 3.7.9 on Linux 4.18.0-305.3.1.el8.x86_64-x86_64-with-centos-8.3.2011)
#    (c) 2016-2022 Aldy Authors. All rights reserved.
#    Free for non-commercial/academic use only.
# Genotyping sample MMI011.realigned.bam...
# Potential CYP2C8 gene structures for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Potential major CYP2C8 star-alleles for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Best CYP2C8 star-alleles for MMI011.realigned:
#    1: *1 / *1 (confidence=100%)
#       Minor alleles: *1.001, *1.002
# CYP2C8 results:
#   - *1 / *1
#     Minor: [*1.001] / [*1.002]
#     Legacy notation: [*1A] / [*1B]
# 🐿  Aldy v3.3 (Python 3.7.9 on Linux 4.18.0-305.3.1.el8.x86_64-x86_64-with-centos-8.3.2011)
#    (c) 2016-2022 Aldy Authors. All rights reserved.
#    Free for non-commercial/academic use only.
# Genotyping sample MMI011.realigned.bam...
# Potential CYP2C9 gene structures for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Potential major CYP2C9 star-alleles for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Best CYP2C9 star-alleles for MMI011.realigned:
#    1: *1 / *1 (confidence=100%)
#       Minor alleles: *1.001, *1.006
# CYP2C9 results:
#   - *1 / *1
#     Minor: [*1.001] / [*1.006]
#     Legacy notation: [*1A] / [*1.006]
# 🐿  Aldy v3.3 (Python 3.7.9 on Linux 4.18.0-305.3.1.el8.x86_64-x86_64-with-centos-8.3.2011)
#    (c) 2016-2022 Aldy Authors. All rights reserved.
#    Free for non-commercial/academic use only.
# Genotyping sample MMI011.realigned.bam...
# Potential CYP2D6 gene structures for MMI011.realigned:
#    1: 1x*1,1x*36.ALDY (confidence: 100%)
#    2: 1x*1,1x*61 (confidence: 100%)
# Potential major CYP2D6 star-alleles for MMI011.realigned:
#    1: 1x*10, 1x*36.ALDY (confidence: 100%)
# Best CYP2D6 star-alleles for MMI011.realigned:
#    1: *10 / *36.ALDY (confidence=100%)
#       Minor alleles: *10.002, *36.1001
# CYP2D6 results:
#   - *10 / *36.ALDY
#     Minor: [*10.002] / [*36.1001]
#     Legacy notation: [*10B] / [*36.ALDY]
# 🐿  Aldy v3.3 (Python 3.7.9 on Linux 4.18.0-305.3.1.el8.x86_64-x86_64-with-centos-8.3.2011)
#    (c) 2016-2022 Aldy Authors. All rights reserved.
#    Free for non-commercial/academic use only.
# Genotyping sample MMI011.realigned.bam...
# Potential CYP3A5 gene structures for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Potential major CYP3A5 star-alleles for MMI011.realigned:
#    1: 2x*3 (confidence: 100%)
# Best CYP3A5 star-alleles for MMI011.realigned:
#    1: *3 / *3 (confidence=100%)
#       Minor alleles: *3.001, *3.001
# CYP3A5 results:
#   - *3 / *3
#     Minor: [*3.001] / [*3.001]
#     Legacy notation: [*3A] / [*3A]
# 🐿  Aldy v3.3 (Python 3.7.9 on Linux 4.18.0-305.3.1.el8.x86_64-x86_64-with-centos-8.3.2011)
#    (c) 2016-2022 Aldy Authors. All rights reserved.
#    Free for non-commercial/academic use only.
# Genotyping sample MMI011.realigned.bam...
# Potential CYP4F2 gene structures for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Potential major CYP4F2 star-alleles for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Best CYP4F2 star-alleles for MMI011.realigned:
#    1: *1 / *1 (confidence=100%)
#       Minor alleles: *1.001, *1.001
# CYP4F2 results:
#   - *1 / *1
#     Minor: [*1.001] / [*1.001]
#     Legacy notation: [*1] / [*1]
# 🐿  Aldy v3.3 (Python 3.7.9 on Linux 4.18.0-305.3.1.el8.x86_64-x86_64-with-centos-8.3.2011)
#    (c) 2016-2022 Aldy Authors. All rights reserved.
#    Free for non-commercial/academic use only.
# Genotyping sample MMI011.realigned.bam...
# Potential DPYD gene structures for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Potential major DPYD star-alleles for MMI011.realigned:
#    1: 1x*1, 1x*rs17376848 (confidence: 100%)
# Best DPYD star-alleles for MMI011.realigned:
#    1: *1 / *rs17376848 (confidence=100%)
#       Minor alleles: *1, *rs17376848
# DPYD results:
#   - *1 / *rs17376848
#     Minor: [*1] / [*rs17376848]
#     Legacy notation: [*1] / [*rs17376848]
# 🐿  Aldy v3.3 (Python 3.7.9 on Linux 4.18.0-305.3.1.el8.x86_64-x86_64-with-centos-8.3.2011)
#    (c) 2016-2022 Aldy Authors. All rights reserved.
#    Free for non-commercial/academic use only.
# Genotyping sample MMI011.realigned.bam...
# Average sample coverage is 19.09512994781937. We recommend at least 20x coverage for the best results.
# Potential G6PD gene structures for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Potential major G6PD star-alleles for MMI011.realigned:
#    1: 2x*B (confidence: 100%)
# Best G6PD star-alleles for MMI011.realigned:
#    1: *B / *B (confidence=100%)
#       Minor alleles: *B, *B
# G6PD results:
#   - *B / *B
#     Minor: [*B] / [*B]
#     Legacy notation: [*B (wildtype)] / [*B (wildtype)]
# 🐿  Aldy v3.3 (Python 3.7.9 on Linux 4.18.0-305.3.1.el8.x86_64-x86_64-with-centos-8.3.2011)
#    (c) 2016-2022 Aldy Authors. All rights reserved.
#    Free for non-commercial/academic use only.
# Genotyping sample MMI011.realigned.bam...
# Potential IFNL3 gene structures for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Potential major IFNL3 star-alleles for MMI011.realigned:
#    1: 2x*normal (confidence: 100%)
# Best IFNL3 star-alleles for MMI011.realigned:
#    1: *normal / *normal (confidence=100%)
#       Minor alleles: *normal, *normal
# IFNL3 results:
#   - *normal / *normal
#     Minor: [*normal] / [*normal]
#     Legacy notation: [*normal] / [*normal]
# 🐿  Aldy v3.3 (Python 3.7.9 on Linux 4.18.0-305.3.1.el8.x86_64-x86_64-with-centos-8.3.2011)
#    (c) 2016-2022 Aldy Authors. All rights reserved.
#    Free for non-commercial/academic use only.
# Genotyping sample MMI011.realigned.bam...
# Potential NUDT15 gene structures for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Potential major NUDT15 star-alleles for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Best NUDT15 star-alleles for MMI011.realigned:
#    1: *1 / *1 (confidence=100%)
#       Minor alleles: *1.001, *1.001
# NUDT15 results:
#   - *1 / *1
#     Minor: [*1.001] / [*1.001]
#     Legacy notation: [*1.001] / [*1.001]
# 🐿  Aldy v3.3 (Python 3.7.9 on Linux 4.18.0-305.3.1.el8.x86_64-x86_64-with-centos-8.3.2011)
#    (c) 2016-2022 Aldy Authors. All rights reserved.
#    Free for non-commercial/academic use only.
# Genotyping sample MMI011.realigned.bam...
# Potential SLCO1B1 gene structures for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Potential major SLCO1B1 star-alleles for MMI011.realigned:
#    1: 1x*1, 1x*1B & rs4149057, rs2291075 (confidence: 100%)
# Best SLCO1B1 star-alleles for MMI011.realigned:
#    1: *1+rs4149057+rs2291075 / *1B (confidence=100%)
#       Minor alleles: *1.001 +rs4149057 +rs2291075, *1.002
# SLCO1B1 results:
#   - *1+rs4149057+rs2291075 / *1B
#     Minor: [*1.001 +rs4149057 +rs2291075] / [*1.002]
#     Legacy notation: [*1A +rs4149057 +rs2291075] / [*1B]
# WARNING: mutations rs2291075, rs4149057 suggest presence of a novel major star-allele.
# However, such alleles cannot be determined without phasing data.
# Please provide --phase parameter for Aldy to accurately call novel major star-alleles.
# The above-reported assignments of these mutations are random.
# 🐿  Aldy v3.3 (Python 3.7.9 on Linux 4.18.0-305.3.1.el8.x86_64-x86_64-with-centos-8.3.2011)
#    (c) 2016-2022 Aldy Authors. All rights reserved.
#    Free for non-commercial/academic use only.
# Genotyping sample MMI011.realigned.bam...
# Potential TPMT gene structures for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Potential major TPMT star-alleles for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Best TPMT star-alleles for MMI011.realigned:
#    1: *1 / *1 (confidence=100%)
#       Minor alleles: *1.001, *1.001
# TPMT results:
#   - *1 / *1
#     Minor: [*1.001] / [*1.001]
#     Legacy notation: [*1] / [*1]
# 🐿  Aldy v3.3 (Python 3.7.9 on Linux 4.18.0-305.3.1.el8.x86_64-x86_64-with-centos-8.3.2011)
#    (c) 2016-2022 Aldy Authors. All rights reserved.
#    Free for non-commercial/academic use only.
# Genotyping sample MMI011.realigned.bam...
# Potential UGT1A1 gene structures for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Potential major UGT1A1 star-alleles for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Best UGT1A1 star-alleles for MMI011.realigned:
#    1: *1 / *1 (confidence=100%)
#       Minor alleles: *1.001, *1.001
# UGT1A1 results:
#   - *1 / *1
#     Minor: [*1.001] / [*1.001]
#     Legacy notation: [*1] / [*1]
# 🐿  Aldy v3.3 (Python 3.7.9 on Linux 4.18.0-305.3.1.el8.x86_64-x86_64-with-centos-8.3.2011)
#    (c) 2016-2022 Aldy Authors. All rights reserved.
#    Free for non-commercial/academic use only.
# Genotyping sample MMI011.realigned.bam...
# Potential VKORC1 gene structures for MMI011.realigned:
#    1: 2x*1 (confidence: 100%)
# Potential major VKORC1 star-alleles for MMI011.realigned:
#    1: 1x*T, 1x*normal (confidence: 100%)
# Best VKORC1 star-alleles for MMI011.realigned:
#    1: *T / *normal (confidence=100%)
#       Minor alleles: *T, *normal
# VKORC1 results:
#   - *T / *normal
#     Minor: [*T] / [*normal]
#     Legacy notation: [*T] / [*normal]
# Traceback (most recent call last):
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/stargazer.py", line 145, in <module>
#     main()
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/stargazer.py", line 133, in main
#     TOOLS[args.tool].run(args)
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/genotype.py", line 1305, in run
#     conformed_vcf = conform_vcf(processed_vcf, ref_vcf) # step 4
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/genotype.py", line 907, in conform_vcf
#     fields1[9:] = [f(x) for x in fields1[9:]]
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/genotype.py", line 907, in <listcomp>
#     fields1[9:] = [f(x) for x in fields1[9:]]
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/genotype.py", line 904, in f
#     ad2[mapping[i]] = ad1[i]
# KeyError: 3
# Traceback (most recent call last):
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/stargazer.py", line 145, in <module>
#     main()
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/stargazer.py", line 133, in main
#     TOOLS[args.tool].run(args)
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/genotype.py", line 1305, in run
#     conformed_vcf = conform_vcf(processed_vcf, ref_vcf) # step 4
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/genotype.py", line 907, in conform_vcf
#     fields1[9:] = [f(x) for x in fields1[9:]]
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/genotype.py", line 907, in <listcomp>
#     fields1[9:] = [f(x) for x in fields1[9:]]
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/genotype.py", line 904, in f
#     ad2[mapping[i]] = ad1[i]
# KeyError: 3
# Traceback (most recent call last):
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/stargazer.py", line 145, in <module>
#     main()
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/stargazer.py", line 133, in main
#     TOOLS[args.tool].run(args)
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/genotype.py", line 1305, in run
#     conformed_vcf = conform_vcf(processed_vcf, ref_vcf) # step 4
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/genotype.py", line 907, in conform_vcf
#     fields1[9:] = [f(x) for x in fields1[9:]]
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/genotype.py", line 907, in <listcomp>
#     fields1[9:] = [f(x) for x in fields1[9:]]
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/genotype.py", line 904, in f
#     ad2[mapping[i]] = ad1[i]
# KeyError: 3
# Traceback (most recent call last):
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/stargazer.py", line 145, in <module>
#     main()
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/stargazer.py", line 133, in main
#     TOOLS[args.tool].run(args)
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/genotype.py", line 1305, in run
#     conformed_vcf = conform_vcf(processed_vcf, ref_vcf) # step 4
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/genotype.py", line 907, in conform_vcf
#     fields1[9:] = [f(x) for x in fields1[9:]]
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/genotype.py", line 907, in <listcomp>
#     fields1[9:] = [f(x) for x in fields1[9:]]
#   File "/home/webb/pharm/pharm_pipe/lib/Stargazer_v1.0.8/genotype.py", line 904, in f
#     ad2[mapping[i]] = ad1[i]
# KeyError: 3
# MMI012
# INFO:root:Processing sample MMI012.realigned at 2022-03-02 01:09:12.895708
# INFO:root:Writing to json at 2022-03-02 01:09:59.231606
# INFO:root:Writing to tsv at 2022-03-02 01:09:59.232741
# Call Cyrius to out/MMI012/cyrius_MMI012 done!
